# %% [markdown]
# # Case Study 2: Amazon Review based Product Rating
#
# We have used the Toys and Games 5-core dataset from [Amazon Product review Dataset](http://jmcauley.ucsd.edu/data/amazon/).  We have to convert given reviews into features which can be used for rating the product. Each review can have an integer rating value from 1 to 5.
#
# **Few Reviews with rating 5: **
# 1. I like the item pricing. My granddaughter wanted to mark on it but I wanted it just for the letters.
# 2. Bought one a few years ago for my daughter and she loves it, still using it today. For the holidays we bought one for our niece and she loved it too
#
# **Few Reviews with rating 1:**
# 1. no more taking Irish car bombs with strange Australian women who can drink like rockstars...my head hurts.
#
#
# Let's try to make a sentiment Analyzer using this dataset which has 167,597 reviews. The Ground truth is in range of 1-5 from 1 being bad review to 5 being good review.

# %%
###Load the Dataset
import pandas as pd
data = pd.read_csv("product_rating.csv")
data
# Out:
#         Unnamed: 0                                            reviews  ratings
# 0                0  I like the item pricing. My granddaughter want...      5.0
# 1                1  Love the magnet easel... great for moving to d...      4.0
# 2                2  Both sides are magnetic.  A real plus when you...      5.0
# 3                3  Bought one a few years ago for my daughter and...      5.0
# 4                4  I have a stainless steel refrigerator therefor...      4.0
# 5                5  this is a nice magnetic board for the kids to ...      3.0
# 6                6  This is just as I expected. It's not too sturd...      3.0
# 7                7  My granddaughter really really likes this. I l...      5.0
# 8                8  This is good product to have with unlimited po...      4.0
# 9                9  I keep this board on top of the hallway table ...      3.0
# 10              10  Very nice to use with magnet letters and pract...      5.0
# 11              11  Bought this board along with Melissa and Doug ...      5.0
# 12              12  The board had to be put away for my 18 month o...      3.0
# 13              13  sturdy and perfect for coffee table. magnets s...      5.0
# 14              14  We had purchased Melissa & Doug magnets & had ...      5.0
# 15              15  We purchased this to go with the magnetic lett...      5.0
# 16              16  This easel is the perfect size for my three ye...      5.0
# 17              17  This is my absolute favorite design book. The ...      5.0
# 18              18  Working with Mandala type coloring books can t...      4.0
# 19              19  This book contains 30 full page designs that a...      5.0
# 20              20  Prepare to be swept away by the beauty of the ...      5.0
# 21              21  Oh, and for my teenager too.  Because that's w...      5.0
# 22              22  Very nice for time destraction. Bought for my ...      5.0
# 23              23  I can color right along with my grandchildren,...      5.0
# 24              24  This coloring book has provided hours of creat...      5.0
# 25              25  The pictures in this book are very detailed an...      3.0
# 26              26  I just recieved my copy of decorative tile des...      3.0
# 27              27  The art is nice in this coloring book. But I f...      4.0
# 28              28  This book looks really fun and cool. Haven't o...      4.0
# 29              29  Bought this book for my optical illusion obses...      3.0
# ...            ...                                                ...      ...
# 167567      167567  This is a very cute speaker. Just as shown, pa...      5.0
# 167568      167568  The instructions that came with this item were...      4.0
# 167569      167569  The Omaker M3 is a nice, well designed portabl...      5.0
# 167570      167570  If someone in the household has an old school ...      5.0
# 167571      167571  Nobody can resist working with this cube. It's...      4.0
# 167572      167572  As a child of the 80's, I have seen Rubik's cu...      2.0
# 167573      167573  A few years ago when I was a teen (okay, quite...      5.0
# 167574      167574  Effortless.  This is the fastest cube I have p...      5.0
# 167575      167575  I was so impressed with the Panther Drone when...      5.0
# 167576      167576  This baby is easy to use and goes fast! It wil...      5.0
# 167577      167577  This is a wonderful stunt helicopter with a ni...      5.0
# 167578      167578  I'm a mother with a little girl who likes to p...      5.0
# 167579      167579  This drone sturdy and lightweight! I loved fly...      5.0
# 167580      167580  my nephew loved this Panther Drone. I'm glad I...      5.0
# 167581      167581  These babies go fast and are pretty easy to co...      5.0
# 167582      167582  my son and I fight over this item all of the t...      5.0
# 167583      167583  The Panther Drone UFO RC Quadcopter is nothing...      5.0
# 167584      167584  Amazingly easy to handle, love the stunts. Ver...      5.0
# 167585      167585  I bought the Panther Drone UFO for my son, he ...      5.0
# 167586      167586  Wow, this thing can move!  I found this UFO to...      5.0
# 167587      167587  Drones are in the news a lot these days.  Now ...      4.0
# 167588      167588  This toy was a HIT with my nephews! They absol...      5.0
# 167589      167589  My son absolutely loves The Panther Drone Quad...      5.0
# 167590      167590  Its sure hard to break and really easy to cont...      5.0
# 167591      167591  Ive owned other helicopters in the past, the o...      5.0
# 167592      167592  This drone is very fun and super duarable. Its...      5.0
# 167593      167593  This is my brother's most prized toy. It's ext...      5.0
# 167594      167594  This Panther Drone toy is awesome. I definitel...      5.0
# 167595      167595  This is my first drone and it has proven to be...      5.0
# 167596      167596  This is a super fun toy to have around. In our...      4.0
#
# [167597 rows x 3 columns]

# %% [markdown]
# ## Exercise 1
# Modify the reviews such that the irrelevant words and characters are removed. To this end apply the following preprocessing.
# 1. **Case** Convert the reviews to lower case.
# 2. **URLs** We don't intend to follow the (short) urls and determine the content of the site, so we can eliminate all of these URLs via regular expression matching or replace with generic word URL.
# 3. **Username** We can eliminate "$@$username" via regex matching or replace it with generic word AT\_USER
# 4. **hashtag** hash tags can give us some useful information, so replace them with the exact same word without the hash. E.g. \#nike replaced with 'nike'.
# 5. **Whitespace** Replace multiple whitespaces with a single whitespace.
# 6. **Stop words** a, is, the, with etc. The full list of stop words can be found at Stop Word List. These words don't indicate any sentiment and can be removed.
# 7. **Repeated letters** Sometimes people repeat letters to stress the emotion. "aaaaawesome" for awesome. We can look for 2 or more repetitive letters in words and replace them by 2 of the same.
# 8. **Punctuation** Remove punctuation such as comma, single/double quote, question marks at the start and end of each word. E.g. beautiful!!!!!! replaced with beautiful
# 9. **Non-alpha Words**  Remove all those words which don't start with an alphabet. E.g. 15th, 5.34am
#
# After preprocessing you should have obtain as shown below:
#
# Can you write your code for pre processing?

# %%
## Your code here

# %% [markdown]
# ## Exercise 2
# Write the code to count the number of positive and negative words in each product review? You can use [Positive_words.txt](https://drive.google.com/drive/folders/1TnJCyn4LiS6InT35skvCbbBrp37AGYc) and [Negative words.txt](https://drive.google.com/drive/folders/1TnJCyn4LiS6InT35skvCbbBrp37AGYcT}{negative\_words.txt) which contain positive words and negative words respectively?

# %%
## your code here

# %% [markdown]
# ## Exercise  3
# Take the one feature as the number of positive words and other as number of negative words for each review and use them in a KNN Classifier. What is the accuracy obtained?

# %%
## Your code here

# %% [markdown]
# ## Exercise 4
# Take the one feature as the number of positive words and other as number of negative words for each review and use them in a Linear Classifier. What is the accuracy obtained?

# %%
## Your code here

# %% [markdown]
# ## Exercise 5
# Take the one feature as the number of positive words and other as number of negative words for each review and use them in a Naive Baeyes Classifier. What is the accuracy obtained?

# %%
## Your code here

# %% [markdown]
# ## Exercise 6
# Calculate precision and Recall for the product review problem using all three classifiers and plot precision-Recall curve for all?

# %%
## Your code here
